# %%
import tkinter as tk
from tkinter import messagebox

def valider(tab, row, col, num):
    # Vérifier si le nombre est déjà présent dans la ligne
    for i in range(9):
        if tab[row][i] == num:
            return False

    # Vérifier si le nombre est déjà présent dans la colonne
    for i in range(9):
        if tab[i][col] == num:
            return False

    # Vérifier si le nombre est déjà présent dans la sous-grille 3x3
    debut_row = row - row % 3
    debut_col = col - col % 3
    for i in range(3):
        for j in range(3):
            if tab[i + debut_row][j + debut_col] == num:
                return False

    return True

def sudoku(tab):
    for row in range(9):
        for col in range(9):
            if tab[row][col] == 0:
                for num in range(1, 10):
                    if valider(tab, row, col, num):
                        tab[row][col] = num
                        if sudoku(board):
                            return True
                        tab[row][col] = 0
                return False
    return True

def initialise_tab():
    # Grille par défaut
    tab = [
        [5, 3, 0, 0, 7, 0, 0, 0, 0],
        [6, 0, 0, 1, 9, 5, 0, 0, 0],
        [0, 9, 8, 0, 0, 0, 0, 6, 0],
        [8, 0, 0, 0, 6, 0, 0, 0, 3],
        [4, 0, 0, 8, 0, 3, 0, 0, 1],
        [7, 0, 0, 0, 2, 0, 0, 0, 6],
        [0, 6, 0, 0, 0, 0, 2, 8, 0],
        [0, 0, 0, 4, 1, 9, 0, 0, 5],
        [0, 0, 0, 0, 8, 0, 0, 7, 9]
    ]

    # Remplir la grille avec les valeurs par défaut
    for row in range(9):
        for col in range(9):
            if tab[row][col] != 0:
                tab_entrer[row][col].delete(0, tk.END)
                tab_entrer[row][col].insert(0, tab[row][col])

def valider_donnee_sol():
    # Lire les valeurs entrées par l'utilisateur
    for row in range(9):
        for col in range(9):
            try:
                num = int(tab_entrer[row][col].get())
                if num < 1 or num > 9:
                    raise ValueError
                tab[row][col] = num
            except ValueError:
                tab[row][col] = 0
                tab_entrer[row][col].delete(0, tk.END)

    # Résoudre le puzzle Sudoku
    if sudoku(tab):
        # Afficher la grille résolue
        for row in range(9):
            for col in range(9):
                tab_entrer[row][col].delete(0, tk.END)
                tab_entrer[row][col].insert(0, tab[row][col])
    else:
        messagebox.showerror("Erreur", "Pas de solution trouvée pour ce puzzle Sudoku.")

# Créer une fenêtre
window = tk.Tk()
window.title("la solution de ce puzzle Sudoku")

# Créer une grille pour le puzzle
tab = [[0 for _ in range(9)] for _ in range(9)]

# Créer les champs de saisie pour l'utilisateur
tab_entrer = [[None for _ in range(9)] for _ in range(9)]
for row in range(9):
    for col in range(9):
        tab_entrer[row][col] = tk.Entry(window, width=2, font=("Arial", 20), justify="center")
        tab_entrer[row][col].grid(row=row, column=col, padx=1, pady=1)

# Créer un bouton pour initialiser la grille avec les valeurs par défaut
initialise_button = tk.Button(window, text="Initialiser", font=("Arial", 14), command=initialise_tab)
initialise_button.grid(row=9, column=0, columnspan=9, pady=10)

# Créer un bouton pour valider et résoudre le puzzle
valider_button = tk.Button(window, text="Résoudre", font=("Arial", 14), command=valider_donnee_sol)
valider_button.grid(row=10, column=0, columnspan=9, pady=10)

# Lancer la boucle principale de la fenêtre
window.mainloop()
